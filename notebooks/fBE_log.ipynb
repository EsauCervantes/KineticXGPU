# %%
import sys
sys.path.append("src_log")

# %%
import numpy as np
import torch

# Choose device
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float64

print("Using device:", device)

import grid_log
import importlib
import cosmology
import collision_log
#from kinematics import energy, cosphi, mandelstam_s_t, sqrt_one_minus_cosphi2

from cosmology import StdCosmology, build_T_of_a_table
#from grid_log import make_log_q_grid, interp_nearest_log_uniform_vec

#from grid import grid_edges_from_centers, bin_widths_from_centers, from grid import, interp_linear_uniform

import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
# Out:
# Using device: cpu

# %%
from grid_log import make_log_q_grid as mygrid

qmin = 10**(-3)
qmax = 10**2
N = 100
a =1

q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)
p = q / a

# %%
cosmo = StdCosmology(gstar=106.75)
T_of_a, H_of_a, (amin, amax) = build_T_of_a_table(cosmo, Trh=150.0, ai=1.0)

print(amin, amax)
print(T_of_a(1.0), H_of_a(1.0))
# Out:
# 0.9999999999999998 1500000.0
# 150.0 3.16152130195488e-14

# %%
T_of_a(10.)
# Out:
# array(15.00000087)

# %%
H_of_a(10.)
# Out:
# 3.1615216686597294e-16

# %% [markdown]
# # Checking the kernel of the collision operator F

# %%
from functools import partial
import solver
import func

from func import gamma_ap_to_ff,  gamma_ap_total_to_sm_fermions
from solver import integrate_rk4_a, integrate_rk4_a_trajectory

# %% [markdown]
# # Computing $C_\text{IF}$ as a check

# %% [markdown]
# # We try to solve the equation just with FI dynamics

# %%
alpha = 1/137

# Rough width: Gamma ~ alpha * eps^2 * m
lam = 0.05
g = 0.01
v = 1
mA = g*v
mh = np.sqrt(lam/3)*v

eps = 6e-10
m_med = mA
Gamma = alpha * eps**2 * m_med

Gamma = gamma_ap_total_to_sm_fermions(
    mA, eps,
    alpha_em=1/137.035999084,
    include=("e","mu","tau","u","d","s","c","b","t"),
)

gchi = 1.
#lam = 0*1e-3
#m_med = 0.018
#m_med = mA

# %%
mh
# Out:
# 0.12909944487358055

# %%
mA
# Out:
# 0.01

# %%
Gamma
# Out:
# 2.1766839253524552e-23

# %%
# Choose grid and params (keep modest while testing)
from collision_log import rhs_dfFI_da_torch

N = 90
qmin = 10**(-3)
qmax = 10**3
#a =1

batch_size = 32

q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)
#p = q / a

# %%
a0 = 1.0
a1 = 5.
n_steps = 100


rhsFI = partial(
    rhs_dfFI_da_torch,
    q=q, dq=dlogq, m=mA, lam=lam,
    H_of_a=H_of_a, T_of_a=T_of_a,
    m_med=mA, Gamma=Gamma, pref_FI=1.0,
    gchi=gchi, batch_size=batch_size
)

f0 = torch.zeros_like(q)   # (N,)
f1 = integrate_rk4_a(f0, a0, a1, n_steps, rhsFI)

print("f0:", f0.shape, f0.dtype, f0.device)
print("f1:", f1.shape, f1.dtype, f1.device)
print("finite:", torch.isfinite(f1).all().item())
# Out:
# f0: torch.Size([90]) torch.float64 cpu
# f1: torch.Size([90]) torch.float64 cpu
# finite: True

# %%
Gamma
# Out:
# 2.1766839253524552e-23

# %%
import matplotlib.pyplot as plt
import numpy as np
import func
from func import f_FI_inverse_decay_MB_analytic_p



q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)

a_1 = torch.tensor(a1, device=device, dtype=dtype)



# Physical p, E
p = q/a1

p_cpu  = p.detach().cpu().numpy()
f1_cpu = f1.detach().cpu().numpy()

plt.figure()
plt.plot(p_cpu, f1_cpu)
plt.xlabel("p")
#plt.xscale("log")
plt.ylabel("f1(p)")
plt.yscale("log")
plt.title("f(p) at final a")
plt.grid(True)
plt.show()

plt.figure()
plt.semilogy(p_cpu, np.maximum(f1_cpu, 1e-300))
plt.xlabel("p")
plt.xscale("log")

plt.ylabel("f1(p)")
plt.title("f(p) at final a (log scale)")
plt.grid(True, which="both")
plt.show()

# %%
#Gamma = 1e-20 # GeV (example)
fan = f_FI_inverse_decay_MB_analytic_p(p_cpu, a1, mA, Gamma)


plt.figure()
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(f1_cpu, 1e-300))
#plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fan, 1e-300))

#plt.ylim(10**(-9),1.5*10**(-6))   # set y-axis range
#plt.xlim(10**(-3),10**(1))   # set y-axis range

plt.xlabel("p")
plt.xscale("log")


plt.ylabel(r"$p^2 f(p)$")
plt.yscale("linear")


plt.title(r"$p^2 f(p)$ at final a")
plt.grid(True, which="both")
#plt.show()

# %%
#Gamma = 1e-20 # GeV (example)
fan = f_FI_inverse_decay_MB_analytic_p(p_cpu, a1, mA, Gamma)


plt.figure()
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fan, 1e-300))
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(f1_cpu, 1e-300))

#plt.ylim(10**(-9),1.5*10**(-6))   # set y-axis range
#plt.xlim(10**(-3),10**(1))   # set y-axis range

plt.xlabel("p")
plt.xscale("log")


plt.ylabel(r"$p^2 f(p)$")
plt.yscale("linear")


plt.title(r"$p^2 f(p)$ at final a")
plt.grid(True, which="both")
#plt.show()

# %% [markdown]
# # Now with everything included

# %%
alpha = 1/137


# Rough width: Gamma ~ alpha * eps^2 * m
#mA=0.3
#m_t = 0.018


m_med = mA
eps = 6e-10
Gamma = alpha * eps**2 * m_med

Gamma = gamma_ap_total_to_sm_fermions(
    mA, eps,
    alpha_em=1/137.035999084,
    include=("e","mu","tau","u","d","s","c","b","t"),
)

gchi = 1.
lam = 1e-3

#m_med = 0.018
#m_med = mA

# %%
Gamma
# Out:
# 2.1766839253524552e-23

# %%
mA
# Out:
# 0.01

# %%
mh
# Out:
# 0.12909944487358055

# %%
# Choose grid and params (keep modest while testing)
from collision_log import rhs_df_da_torch_logq


N = 90
qmin = 10**(-3)
qmax = 10**3
#a0 = 1
#a1 = 5.


batch_size = 32

q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)
p = q / a

f0 = torch.zeros_like(q)   # (N,)

rhs = partial(
    rhs_df_da_torch_logq,
    q=q,
    logq0=logq0,
    dlogq=dlogq,
    log_space=log_space,
    m=mh,
    lam=lam,
    H_of_a=H_of_a,
    T_of_a=T_of_a,
    m_med=mA,
    Gamma=Gamma,
    pref_FI=1.0,
    gchi=gchi,
    batch_size=batch_size
)

# now rhs has signature rhs(f,a)
fall = integrate_rk4_a(f0, a0, a1, n_steps, rhs)
# Out:
# weighted outside (loss) fraction: 0.0
# weighted outside (loss) fraction: 0.0
# weighted outside (loss) fraction: 0.0
# weighted outside (loss) fraction: 6.158688802840537e-12
# weighted outside (loss) fraction: 7.387198189840842e-11
# weighted outside (loss) fraction: 2.1038174635234719e-10
# weighted outside (loss) fraction: 6.351087645047682e-12
# weighted outside (loss) fraction: 7.518266082781761e-11
# weighted outside (loss) fraction: 2.188315045338755e-10
# weighted outside (loss) fraction: 6.351114244371538e-12
# weighted outside (loss) fraction: 7.523063814318973e-11
# weighted outside (loss) fraction: 2.1883371362013219e-10
# weighted outside (loss) fraction: 6.353297488067107e-12
# weighted outside (loss) fraction: 7.52497613662951e-11
# weighted outside (loss) fraction: 2.1891791287469913e-10
# weighted outside (loss) fraction: 6.418727184372283e-12
# weighted outside (loss) fraction: 7.577678827466384e-11
# weighted outside (loss) fraction: 2.2179952893897662e-10
# weighted outside (loss) fraction: 6.487951961639359e-12
# weighted outside (loss) fraction: 7.625316988874417e-11
# weighted outside (loss) fraction: 2.248408363272694e-10
# weighted outside (loss) fraction: 6.553445808147358e-12
# weighted outside (loss) fraction: 7.674078332270489e-11
# weighted outside (loss) fraction: 2.2774641732959865e-10
# weighted outside (loss) fraction: 6.5545530280302525e-12
# weighted outside (loss) fraction: 7.675051035699429e-11
# weighted outside (loss) fraction: 2.2778930513073856e-10
# weighted outside (loss) fraction: 6.635465820021669e-12
# weighted outside (loss) fraction: 7.743078598928453e-11
# weighted outside (loss) fraction: 2.3137520676178042e-10
# weighted outside (loss) fraction: 6.680048404611692e-12
# weighted outside (loss) fraction: 7.774007186567172e-11
# weighted outside (loss) fraction: 2.333362503091872e-10
# weighted outside (loss) fraction: 6.761350286005262e-12
# weighted outside (loss) fraction: 7.835690398115088e-11
# weighted outside (loss) fraction: 2.369656705781727e-10
# weighted outside (loss) fraction: 6.762097771559006e-12
# weighted outside (loss) fraction: 7.836348495509534e-11
# weighted outside (loss) fraction: 2.3699475866299647e-10
# weighted outside (loss) fraction: 6.851364369486982e-12
# weighted outside (loss) fraction: 7.899837965745889e-11
# weighted outside (loss) fraction: 2.409955093199858e-10
# weighted outside (loss) fraction: 6.885377292091877e-12
# weighted outside (loss) fraction: 7.923580243007535e-11
# weighted outside (loss) fraction: 2.424946557300417e-10
# weighted outside (loss) fraction: 6.975424961087929e-12
# weighted outside (loss) fraction: 7.995931442823804e-11
# weighted outside (loss) fraction: 2.4653904153517564e-10
# weighted outside (loss) fraction: 6.975991502297842e-12
# weighted outside (loss) fraction: 7.996430333120734e-11
# weighted outside (loss) fraction: 2.4656119909445705e-10
# weighted outside (loss) fraction: 7.0712595635973626e-12
# weighted outside (loss) fraction: 8.066653342009904e-11
# weighted outside (loss) fraction: 2.508660934128412e-10
# weighted outside (loss) fraction: 7.099393941813724e-12
# weighted outside (loss) fraction: 8.086393744024581e-11
# weighted outside (loss) fraction: 2.5210942570002563e-10
# weighted outside (loss) fraction: 7.195549889948444e-12
# weighted outside (loss) fraction: 8.15850288084318e-11
# weighted outside (loss) fraction: 2.565339351953602e-10
# weighted outside (loss) fraction: 7.19600769765601e-12
# weighted outside (loss) fraction: 8.158905950656857e-11
# weighted outside (loss) fraction: 2.5655193802255683e-10
# weighted outside (loss) fraction: 7.296249942569351e-12
# weighted outside (loss) fraction: 8.234269880797776e-11
# weighted outside (loss) fraction: 2.6124188790884674e-10
# weighted outside (loss) fraction: 7.320637682985118e-12
# weighted outside (loss) fraction: 8.251437136764168e-11
# weighted outside (loss) fraction: 2.62323894691706e-10
# weighted outside (loss) fraction: 7.421855096206248e-12
# weighted outside (loss) fraction: 8.328893757733202e-11
# weighted outside (loss) fraction: 2.6692038459219024e-10
# weighted outside (loss) fraction: 7.422239999998395e-12
# weighted outside (loss) fraction: 8.329232360645547e-11
# weighted outside (loss) fraction: 2.669356079270096e-10
# weighted outside (loss) fraction: 7.526812231438051e-12
# weighted outside (loss) fraction: 8.403939736648235e-11
# weighted outside (loss) fraction: 2.7172580675941505e-10
# weighted outside (loss) fraction: 7.548600956865889e-12
# weighted outside (loss) fraction: 8.419324621127698e-11
# weighted outside (loss) fraction: 2.7269589324555205e-10
# weighted outside (loss) fraction: 7.654228264745328e-12
# weighted outside (loss) fraction: 8.50072905533251e-11
# weighted outside (loss) fraction: 2.7752094562463e-10
# weighted outside (loss) fraction: 7.654561101098375e-12
# weighted outside (loss) fraction: 8.501021400329584e-11
# weighted outside (loss) fraction: 2.775341792613004e-10
# weighted outside (loss) fraction: 7.762874939349154e-12
# weighted outside (loss) fraction: 8.578583748537717e-11
# weighted outside (loss) fraction: 2.825810015438714e-10
# weighted outside (loss) fraction: 7.782754138140734e-12
# weighted outside (loss) fraction: 8.592645093208523e-11
# weighted outside (loss) fraction: 2.834696058974317e-10
# weighted outside (loss) fraction: 7.892282461991756e-12
# weighted outside (loss) fraction: 8.669624084681313e-11
# weighted outside (loss) fraction: 2.885206396752379e-10
# weighted outside (loss) fraction: 7.892575771913803e-12
# weighted outside (loss) fraction: 8.669881013405069e-11
# weighted outside (loss) fraction: 2.885323679799341e-10
# weighted outside (loss) fraction: 8.004663459285978e-12
# weighted outside (loss) fraction: 8.74781648650085e-11
# weighted outside (loss) fraction: 2.9389046424192527e-10
# weighted outside (loss) fraction: 8.02307902567457e-12
# weighted outside (loss) fraction: 8.76085173611805e-11
# weighted outside (loss) fraction: 2.9471747392493436e-10
# weighted outside (loss) fraction: 8.136326459877636e-12
# weighted outside (loss) fraction: 8.83958734981935e-11
# weighted outside (loss) fraction: 2.9999031301173716e-10
# weighted outside (loss) fraction: 8.136588651879563e-12
# weighted outside (loss) fraction: 8.839816226493455e-11
# weighted outside (loss) fraction: 3.00000861870747e-10
# weighted outside (loss) fraction: 8.25218589357207e-12
# weighted outside (loss) fraction: 8.924812005036783e-11
# weighted outside (loss) fraction: 3.0537275491684454e-10
# weighted outside (loss) fraction: 8.269442562872702e-12
# weighted outside (loss) fraction: 8.937035038142141e-11
# weighted outside (loss) fraction: 3.0615104475832323e-10
# weighted outside (loss) fraction: 8.38617297131677e-12
# weighted outside (loss) fraction: 9.018049723351721e-11
# weighted outside (loss) fraction: 3.116772068558355e-10
# weighted outside (loss) fraction: 8.38641047189265e-12
# weighted outside (loss) fraction: 9.018256401677702e-11
# weighted outside (loss) fraction: 3.1168681615230784e-10
# weighted outside (loss) fraction: 8.505325857243536e-12
# weighted outside (loss) fraction: 9.102952632690834e-11
# weighted outside (loss) fraction: 3.1738289557435386e-10
# weighted outside (loss) fraction: 8.521642439139451e-12
# weighted outside (loss) fraction: 9.114503135994422e-11
# weighted outside (loss) fraction: 3.181225070823642e-10
# weighted outside (loss) fraction: 8.641757356582072e-12
# weighted outside (loss) fraction: 9.199835380999644e-11
# weighted outside (loss) fraction: 3.237605861074968e-10
# weighted outside (loss) fraction: 8.641974228982582e-12
# weighted outside (loss) fraction: 9.200023399113127e-11
# weighted outside (loss) fraction: 3.2376941268682156e-10
# weighted outside (loss) fraction: 8.764223089672284e-12
# weighted outside (loss) fraction: 9.284824465239913e-11
# weighted outside (loss) fraction: 3.296174379654357e-10
# weighted outside (loss) fraction: 8.779761023789547e-12
# weighted outside (loss) fraction: 9.295818705386828e-11
# weighted outside (loss) fraction: 3.303251254519916e-10
# weighted outside (loss) fraction: 8.903128893475104e-12
# weighted outside (loss) fraction: 9.383811972361614e-11
# weighted outside (loss) fraction: 3.361842515401225e-10
# weighted outside (loss) fraction: 8.903328557669798e-12
# weighted outside (loss) fraction: 9.383984360655763e-11
# weighted outside (loss) fraction: 3.3619242510412136e-10
# weighted outside (loss) fraction: 9.028667715809368e-12
# weighted outside (loss) fraction: 9.475059234196969e-11
# weighted outside (loss) fraction: 3.4218131722818564e-10
# weighted outside (loss) fraction: 9.043549591879838e-12
# weighted outside (loss) fraction: 9.485580380840751e-11
# weighted outside (loss) fraction: 3.4286241487370994e-10
# weighted outside (loss) fraction: 9.169918309664071e-12
# weighted outside (loss) fraction: 9.57243796538923e-11
# weighted outside (loss) fraction: 3.489470342732824e-10
# weighted outside (loss) fraction: 9.170103287367114e-12
# weighted outside (loss) fraction: 9.572596998921423e-11
# weighted outside (loss) fraction: 3.489546506366928e-10
# weighted outside (loss) fraction: 9.298535266919255e-12
# weighted outside (loss) fraction: 9.661357844472016e-11
# weighted outside (loss) fraction: 3.550890983510132e-10
# weighted outside (loss) fraction: 9.31285691099618e-12
# weighted outside (loss) fraction: 9.671466160805499e-11
# weighted outside (loss) fraction: 3.557477953421798e-10
# weighted outside (loss) fraction: 9.442446252242505e-12
# weighted outside (loss) fraction: 9.755213133363164e-11
# weighted outside (loss) fraction: 3.619653461208974e-10
# weighted outside (loss) fraction: 9.44261857773946e-12
# weighted outside (loss) fraction: 9.755360554694104e-11
# weighted outside (loss) fraction: 3.6197248036561846e-10
# weighted outside (loss) fraction: 9.574060862142188e-12
# weighted outside (loss) fraction: 9.84538839234286e-11
# weighted outside (loss) fraction: 3.6846373122247726e-10
# weighted outside (loss) fraction: 9.587898477931221e-12
# weighted outside (loss) fraction: 9.855133658686254e-11
# weighted outside (loss) fraction: 3.691035454949254e-10
# weighted outside (loss) fraction: 9.720479234445334e-12
# weighted outside (loss) fraction: 9.946462679882165e-11
# weighted outside (loss) fraction: 3.7551324396635444e-10
# weighted outside (loss) fraction: 9.720640407248189e-12
# weighted outside (loss) fraction: 9.94659988955496e-11
# weighted outside (loss) fraction: 3.7551995641435065e-10
# weighted outside (loss) fraction: 9.855005690321032e-12
# weighted outside (loss) fraction: 1.0041028068599633e-10
# weighted outside (loss) fraction: 3.820811987337099e-10
# weighted outside (loss) fraction: 9.868421304105761e-12
# weighted outside (loss) fraction: 1.005045701193401e-10
# weighted outside (loss) fraction: 3.827046373942405e-10
# weighted outside (loss) fraction: 1.0003998922148456e-11
# weighted outside (loss) fraction: 1.0142142340951442e-10
# weighted outside (loss) fraction: 3.8943856114105435e-10
# weighted outside (loss) fraction: 1.000415029236239e-11
# weighted outside (loss) fraction: 1.014227056559465e-10
# weighted outside (loss) fraction: 3.894449031641213e-10
# weighted outside (loss) fraction: 1.0141498929910543e-11
# weighted outside (loss) fraction: 1.0232545265453497e-10
# weighted outside (loss) fraction: 3.961271662210639e-10
# weighted outside (loss) fraction: 1.0154542492931556e-11
# weighted outside (loss) fraction: 1.0241688283336657e-10
# weighted outside (loss) fraction: 3.9673651583207246e-10
# weighted outside (loss) fraction: 1.0293077655734643e-11
# weighted outside (loss) fraction: 1.0333170189274003e-10
# weighted outside (loss) fraction: 4.0349643954032205e-10
# weighted outside (loss) fraction: 1.0293220540372847e-11
# weighted outside (loss) fraction: 1.0333290616546152e-10
# weighted outside (loss) fraction: 4.035024571936985e-10
# weighted outside (loss) fraction: 1.0433564549015858e-11
# weighted outside (loss) fraction: 1.0428299996576311e-10
# weighted outside (loss) fraction: 4.10369438247394e-10
# weighted outside (loss) fraction: 1.0446278702720383e-11
# weighted outside (loss) fraction: 1.0437190747833407e-10
# weighted outside (loss) fraction: 4.109663008284701e-10
# weighted outside (loss) fraction: 1.0587696258017487e-11
# weighted outside (loss) fraction: 1.0529591156230771e-10
# weighted outside (loss) fraction: 4.180277207816452e-10
# weighted outside (loss) fraction: 1.0587831403052037e-11
# weighted outside (loss) fraction: 1.0529704468384612e-10
# weighted outside (loss) fraction: 4.180334440780815e-10
# weighted outside (loss) fraction: 1.0731008722110903e-11
# weighted outside (loss) fraction: 1.0628634397179495e-10
# weighted outside (loss) fraction: 4.2512833105371577e-10
# weighted outside (loss) fraction: 1.074342883889823e-11
# weighted outside (loss) fraction: 1.0637294469024374e-10
# weighted outside (loss) fraction: 4.257144756520175e-10
# weighted outside (loss) fraction: 1.088757520593414e-11
# weighted outside (loss) fraction: 1.0734544919668799e-10
# weighted outside (loss) fraction: 4.328931730640243e-10
# weighted outside (loss) fraction: 1.0887703337797606e-11
# weighted outside (loss) fraction: 1.0734651820760931e-10
# weighted outside (loss) fraction: 4.328986287947629e-10
# weighted outside (loss) fraction: 1.103360265040574e-11
# weighted outside (loss) fraction: 1.0830166748757306e-10
# weighted outside (loss) fraction: 4.40222941150087e-10
# weighted outside (loss) fraction: 1.1045759282818208e-11
# weighted outside (loss) fraction: 1.0838619863539107e-10
# weighted outside (loss) fraction: 4.4079965841565455e-10
# weighted outside (loss) fraction: 1.1192880153198062e-11
# weighted outside (loss) fraction: 1.0936868747214263e-10
# weighted outside (loss) fraction: 4.482290496209759e-10
# weighted outside (loss) fraction: 1.1193001911306522e-11
# weighted outside (loss) fraction: 1.0936969780396504e-10
# weighted outside (loss) fraction: 4.4823426343997607e-10
# weighted outside (loss) fraction: 1.134178194800715e-11
# weighted outside (loss) fraction: 1.1029764627798128e-10
# weighted outside (loss) fraction: 4.5556704837556984e-10
# weighted outside (loss) fraction: 1.135370057682721e-11
# weighted outside (loss) fraction: 1.103802395583593e-10
# weighted outside (loss) fraction: 4.5613528902837483e-10
# weighted outside (loss) fraction: 1.1503718768718996e-11
# weighted outside (loss) fraction: 1.1135692318516605e-10
# weighted outside (loss) fraction: 4.637988873808932e-10
# weighted outside (loss) fraction: 1.1503834840090681e-11
# weighted outside (loss) fraction: 1.1135788104151678e-10
# weighted outside (loss) fraction: 4.638038832720554e-10
# weighted outside (loss) fraction: 1.1655371324827248e-11
# weighted outside (loss) fraction: 1.123345520954643e-10
# weighted outside (loss) fraction: 4.714309395713204e-10
# weighted outside (loss) fraction: 1.1667075091825266e-11
# weighted outside (loss) fraction: 1.124153892092292e-10
# weighted outside (loss) fraction: 4.719918875182995e-10
# weighted outside (loss) fraction: 1.1819795790530245e-11
# weighted outside (loss) fraction: 1.1344147815913883e-10
# weighted outside (loss) fraction: 4.797077251834107e-10
# weighted outside (loss) fraction: 1.1819906435176909e-11
# weighted outside (loss) fraction: 1.1344238624313505e-10
# weighted outside (loss) fraction: 4.797125124088854e-10
# weighted outside (loss) fraction: 1.1974364173324618e-11
# weighted outside (loss) fraction: 1.1444145120474982e-10
# weighted outside (loss) fraction: 4.876501816280687e-10
# weighted outside (loss) fraction: 1.1985872863741933e-11
# weighted outside (loss) fraction: 1.145206790172981e-10
# weighted outside (loss) fraction: 4.882046682751055e-10
# weighted outside (loss) fraction: 1.2141415591257542e-11
# weighted outside (loss) fraction: 1.1554900912079719e-10
# weighted outside (loss) fraction: 4.962293713524951e-10
# weighted outside (loss) fraction: 1.2141521318398158e-11
# weighted outside (loss) fraction: 1.155498722983055e-10
# weighted outside (loss) fraction: 4.962339711337984e-10
# weighted outside (loss) fraction: 1.2298687742409405e-11
# weighted outside (loss) fraction: 1.1653281826374832e-10
# weighted outside (loss) fraction: 5.042240727046006e-10
# weighted outside (loss) fraction: 1.2310018274737529e-11
# weighted outside (loss) fraction: 1.166105409959574e-10
# weighted outside (loss) fraction: 5.047728043174257e-10
# weighted outside (loss) fraction: 1.2468408899875305e-11
# weighted outside (loss) fraction: 1.1763260732914207e-10
# weighted outside (loss) fraction: 5.128736498975793e-10
# weighted outside (loss) fraction: 1.2468510319937069e-11
# weighted outside (loss) fraction: 1.176334309835706e-10
# weighted outside (loss) fraction: 5.128780836871634e-10
# weighted outside (loss) fraction: 1.2628560131721207e-11
# weighted outside (loss) fraction: 1.186983637651354e-10
# weighted outside (loss) fraction: 5.210575462474358e-10
# weighted outside (loss) fraction: 1.2639728829986874e-11
# weighted outside (loss) fraction: 1.1877473078459833e-10
# weighted outside (loss) fraction: 5.216010941573173e-10
# weighted outside (loss) fraction: 1.28009976520244e-11
# weighted outside (loss) fraction: 1.198081983661053e-10
# weighted outside (loss) fraction: 5.299631971572746e-10
# weighted outside (loss) fraction: 1.2801094654362839e-11
# weighted outside (loss) fraction: 1.1980898169578126e-10
# weighted outside (loss) fraction: 5.299674602644342e-10
# weighted outside (loss) fraction: 1.2963894536665048e-11
# weighted outside (loss) fraction: 1.2085617000490793e-10
# weighted outside (loss) fraction: 5.383772086183308e-10
# weighted outside (loss) fraction: 1.2974914968569996e-11
# weighted outside (loss) fraction: 1.209312394675189e-10
# weighted outside (loss) fraction: 5.389162713340253e-10
# weighted outside (loss) fraction: 1.3138914880779174e-11
# weighted outside (loss) fraction: 1.219876300137256e-10
# weighted outside (loss) fraction: 5.474528375351727e-10
# weighted outside (loss) fraction: 1.3139008062169989e-11
# weighted outside (loss) fraction: 1.2198837876722826e-10
# weighted outside (loss) fraction: 5.474569522146393e-10
# weighted outside (loss) fraction: 1.3304396957471133e-11
# weighted outside (loss) fraction: 1.230376347002812e-10
# weighted outside (loss) fraction: 5.560234736237741e-10
# weighted outside (loss) fraction: 1.3315281450594582e-11
# weighted outside (loss) fraction: 1.2311152263393456e-10
# weighted outside (loss) fraction: 5.5655853271421e-10
# weighted outside (loss) fraction: 1.348200992719619e-11
# weighted outside (loss) fraction: 1.2415973862112848e-10
# weighted outside (loss) fraction: 5.6546103212593e-10
# weighted outside (loss) fraction: 1.3482099338461163e-11
# weighted outside (loss) fraction: 1.2416045299378463e-10
# weighted outside (loss) fraction: 5.654650016874593e-10
# weighted outside (loss) fraction: 1.3650447285569677e-11
# weighted outside (loss) fraction: 1.2523247991656278e-10
# weighted outside (loss) fraction: 5.74538485175668e-10
# weighted outside (loss) fraction: 1.3661207470499004e-11
# weighted outside (loss) fraction: 1.2530525843184718e-10
# weighted outside (loss) fraction: 5.750704849993408e-10
# weighted outside (loss) fraction: 1.3830775167773157e-11
# weighted outside (loss) fraction: 1.2631833760480368e-10
# weighted outside (loss) fraction: 5.839476101605094e-10
# weighted outside (loss) fraction: 1.3830861147866986e-11
# weighted outside (loss) fraction: 1.2631902081677697e-10
# weighted outside (loss) fraction: 5.839514471030629e-10
# weighted outside (loss) fraction: 1.4001983398605478e-11
# weighted outside (loss) fraction: 1.273716659286164e-10
# weighted outside (loss) fraction: 5.930493218172554e-10
# weighted outside (loss) fraction: 1.4012628850422086e-11
# weighted outside (loss) fraction: 1.2744336385324813e-10
# weighted outside (loss) fraction: 5.935782949239108e-10
# weighted outside (loss) fraction: 1.4185111201213881e-11
# weighted outside (loss) fraction: 1.2849999806301212e-10
# weighted outside (loss) fraction: 6.026591550010616e-10
# weighted outside (loss) fraction: 1.418519412840788e-11
# weighted outside (loss) fraction: 1.28500653658124e-10
# weighted outside (loss) fraction: 6.026628729041028e-10
# weighted outside (loss) fraction: 1.4359091727128707e-11
# weighted outside (loss) fraction: 1.295959634707723e-10
# weighted outside (loss) fraction: 6.118526914369469e-10
# weighted outside (loss) fraction: 1.4369632754513143e-11
# weighted outside (loss) fraction: 1.2966668999422216e-10
# weighted outside (loss) fraction: 6.123789876134398e-10
# weighted outside (loss) fraction: 1.4544780947835772e-11
# weighted outside (loss) fraction: 1.307987610483778e-10
# weighted outside (loss) fraction: 6.217063792397783e-10
# weighted outside (loss) fraction: 1.4544860869807788e-11
# weighted outside (loss) fraction: 1.307993897400626e-10
# weighted outside (loss) fraction: 6.217099792764833e-10
# weighted outside (loss) fraction: 1.4721715561935443e-11
# weighted outside (loss) fraction: 1.318836073896296e-10
# weighted outside (loss) fraction: 6.31142849544488e-10
# weighted outside (loss) fraction: 1.473216057618032e-11
# weighted outside (loss) fraction: 1.3195342805691763e-10
# weighted outside (loss) fraction: 6.31666915346339e-10
# weighted outside (loss) fraction: 1.491022807869174e-11
# weighted outside (loss) fraction: 1.3306287483120727e-10
# weighted outside (loss) fraction: 6.412529364844237e-10
# weighted outside (loss) fraction: 1.4910305008070654e-11
# weighted outside (loss) fraction: 1.330634769432156e-10
# weighted outside (loss) fraction: 6.412564176369494e-10
# weighted outside (loss) fraction: 1.5089915270292854e-11
# weighted outside (loss) fraction: 1.341520614291729e-10
# weighted outside (loss) fraction: 6.508403370434828e-10
# weighted outside (loss) fraction: 1.5100272286204153e-11
# weighted outside (loss) fraction: 1.3422102693077634e-10
# weighted outside (loss) fraction: 6.513625184621138e-10
# weighted outside (loss) fraction: 1.5281293571455924e-11
# weighted outside (loss) fraction: 1.3530027104612904e-10
# weighted outside (loss) fraction: 6.610240092152296e-10
# weighted outside (loss) fraction: 1.5281367755963575e-11
# weighted outside (loss) fraction: 1.3530084833982214e-10
# weighted outside (loss) fraction: 6.610273812690864e-10
# weighted outside (loss) fraction: 1.5463808877352883e-11
# weighted outside (loss) fraction: 1.3647437143754659e-10
# weighted outside (loss) fraction: 6.70820773661663e-10
# weighted outside (loss) fraction: 1.5474085534426193e-11
# weighted outside (loss) fraction: 1.3654253776796674e-10
# weighted outside (loss) fraction: 6.713413041809713e-10
# weighted outside (loss) fraction: 1.5657942349385515e-11
# weighted outside (loss) fraction: 1.3771537950032187e-10
# weighted outside (loss) fraction: 6.812056699588892e-10
# weighted outside (loss) fraction: 1.5658014060202542e-11
# weighted outside (loss) fraction: 1.3771593516909113e-10
# weighted outside (loss) fraction: 6.812089432455065e-10
# weighted outside (loss) fraction: 1.584350485854928e-11
# weighted outside (loss) fraction: 1.3883654637663975e-10
# weighted outside (loss) fraction: 6.912767158971343e-10
# weighted outside (loss) fraction: 1.5853707753960833e-11
# weighted outside (loss) fraction: 1.3890397133055477e-10
# weighted outside (loss) fraction: 6.917959329652319e-10
# weighted outside (loss) fraction: 1.6040439055141987e-11
# weighted outside (loss) fraction: 1.400652671191008e-10
# weighted outside (loss) fraction: 7.019057729101767e-10
# weighted outside (loss) fraction: 1.6040508441764407e-11
# weighted outside (loss) fraction: 1.4006580242963604e-10
# weighted outside (loss) fraction: 7.019089528525467e-10
# weighted outside (loss) fraction: 1.6228842672033853e-11
# weighted outside (loss) fraction: 1.4122487363873958e-10
# weighted outside (loss) fraction: 7.121608484482774e-10
# weighted outside (loss) fraction: 1.6238978667862946e-11
# weighted outside (loss) fraction: 1.4129161076018115e-10
# weighted outside (loss) fraction: 7.126790609846121e-10
# weighted outside (loss) fraction: 1.6428495834809805e-11
# weighted outside (loss) fraction: 1.4244055646965685e-10
# weighted outside (loss) fraction: 7.229717895768291e-10
# weighted outside (loss) fraction: 1.6428562849026894e-11
# weighted outside (loss) fraction: 1.424410708963048e-10
# weighted outside (loss) fraction: 7.229748741272756e-10
# weighted outside (loss) fraction: 1.6619708065086276e-11
# weighted outside (loss) fraction: 1.435866095265397e-10
# weighted outside (loss) fraction: 7.334454710180502e-10
# weighted outside (loss) fraction: 1.6629783053037056e-11
# weighted outside (loss) fraction: 1.436526944529323e-10
# weighted outside (loss) fraction: 7.339629356915986e-10
# weighted outside (loss) fraction: 1.6822403022027917e-11
# weighted outside (loss) fraction: 1.4481503718074237e-10
# weighted outside (loss) fraction: 7.449091135237901e-10
# weighted outside (loss) fraction: 1.6822467961527745e-11
# weighted outside (loss) fraction: 1.4481553345876176e-10
# weighted outside (loss) fraction: 7.449121159820801e-10
# weighted outside (loss) fraction: 1.7016602150936318e-11
# weighted outside (loss) fraction: 1.460118102845882e-10
# weighted outside (loss) fraction: 7.556331579893268e-10
# weighted outside (loss) fraction: 1.7026621831487367e-11
# weighted outside (loss) fraction: 1.4607728900450372e-10
# weighted outside (loss) fraction: 7.561504458941134e-10
# weighted outside (loss) fraction: 1.7222161316759965e-11
# weighted outside (loss) fraction: 1.472143954854628e-10
# weighted outside (loss) fraction: 7.668876274731114e-10
# weighted outside (loss) fraction: 1.7222224242954162e-11
# weighted outside (loss) fraction: 1.4721487426146275e-10
# weighted outside (loss) fraction: 7.668905478067477e-10
# weighted outside (loss) fraction: 1.7419447460296792e-11
# weighted outside (loss) fraction: 1.4836103575565824e-10
# weighted outside (loss) fraction: 7.778578964577667e-10
# weighted outside (loss) fraction: 1.7429417997654486e-11
# weighted outside (loss) fraction: 1.4842591289129933e-10
# weighted outside (loss) fraction: 7.783750007475948e-10
# weighted outside (loss) fraction: 1.7628114577846086e-11
# weighted outside (loss) fraction: 1.4960809555162972e-10
# weighted outside (loss) fraction: 7.89492699638582e-10
# weighted outside (loss) fraction: 1.762817529814885e-11
# weighted outside (loss) fraction: 1.4960855525813584e-10
# weighted outside (loss) fraction: 7.894955291584775e-10
# weighted outside (loss) fraction: 1.7828346778074305e-11
# weighted outside (loss) fraction: 1.5079824639062927e-10
# weighted outside (loss) fraction: 8.005917121460865e-10
# weighted outside (loss) fraction: 1.7838273019651108e-11
# weighted outside (loss) fraction: 1.5086258864012305e-10
# weighted outside (loss) fraction: 8.011088893046596e-10
# weighted outside (loss) fraction: 1.803986999372768e-11
# weighted outside (loss) fraction: 1.520827208733227e-10
# weighted outside (loss) fraction: 8.122993865873383e-10
# weighted outside (loss) fraction: 1.8039928873136322e-11
# weighted outside (loss) fraction: 1.5208316470744123e-10
# weighted outside (loss) fraction: 8.123021405886282e-10
# weighted outside (loss) fraction: 1.8243198338996804e-11
# weighted outside (loss) fraction: 1.5328720906826484e-10
# weighted outside (loss) fraction: 8.236639731646961e-10
# weighted outside (loss) fraction: 1.8253085514509917e-11
# weighted outside (loss) fraction: 1.5335106016901793e-10
# weighted outside (loss) fraction: 8.241813987719638e-10
# weighted outside (loss) fraction: 1.8457933909509905e-11
# weighted outside (loss) fraction: 1.545480588905507e-10
# weighted outside (loss) fraction: 8.356206028343231e-10
# weighted outside (loss) fraction: 1.8457990934390632e-11
# weighted outside (loss) fraction: 1.5454848667324519e-10
# weighted outside (loss) fraction: 8.356232800380803e-10
# weighted outside (loss) fraction: 1.8664346192392528e-11
# weighted outside (loss) fraction: 1.5577506269083913e-10
# weighted outside (loss) fraction: 8.472605665293385e-10
# weighted outside (loss) fraction: 1.8674199114606374e-11
# weighted outside (loss) fraction: 1.558384462163632e-10
# weighted outside (loss) fraction: 8.477784951768285e-10
# weighted outside (loss) fraction: 1.8882075535227457e-11
# weighted outside (loss) fraction: 1.57038412274534e-10
# weighted outside (loss) fraction: 8.595026557104627e-10
# weighted outside (loss) fraction: 1.8882130681250823e-11
# weighted outside (loss) fraction: 1.5703882414294927e-10
# weighted outside (loss) fraction: 8.59505254806726e-10
# weighted outside (loss) fraction: 1.9091677847299853e-11
# weighted outside (loss) fraction: 1.5827212889512058e-10
# weighted outside (loss) fraction: 8.713520239434437e-10
# weighted outside (loss) fraction: 1.9101500871780673e-11
# weighted outside (loss) fraction: 1.5833506258324551e-10
# weighted outside (loss) fraction: 8.718706800731501e-10
# weighted outside (loss) fraction: 1.9312616266720376e-11
# weighted outside (loss) fraction: 1.5960567346196198e-10
# weighted outside (loss) fraction: 8.837565957707557e-10
# weighted outside (loss) fraction: 1.9312669875046597e-11
# weighted outside (loss) fraction: 1.5960607252941238e-10
# weighted outside (loss) fraction: 8.837591296665182e-10
# weighted outside (loss) fraction: 1.9525463209841033e-11
# weighted outside (loss) fraction: 1.6089915364476708e-10
# weighted outside (loss) fraction: 8.95749509967221e-10
# weighted outside (loss) fraction: 1.9535261009879256e-11
# weighted outside (loss) fraction: 1.60961716536406e-10
# weighted outside (loss) fraction: 8.962690085600675e-10
# weighted outside (loss) fraction: 1.9749604497345242e-11
# weighted outside (loss) fraction: 1.6219781546164477e-10
# weighted outside (loss) fraction: 9.08439547185444e-10
# weighted outside (loss) fraction: 1.9749656403219508e-11
# weighted outside (loss) fraction: 1.621981999971202e-10
# weighted outside (loss) fraction: 9.084420107521641e-10
# weighted outside (loss) fraction: 1.9965745664465258e-11
# weighted outside (loss) fraction: 1.634641895459824e-10
# weighted outside (loss) fraction: 9.206985335215337e-10
# weighted outside (loss) fraction: 1.9975522839216826e-11
# weighted outside (loss) fraction: 1.635263769269424e-10
# weighted outside (loss) fraction: 9.212191387696278e-10
# weighted outside (loss) fraction: 2.0193111745545007e-11
# weighted outside (loss) fraction: 1.6486862989134356e-10
# weighted outside (loss) fraction: 9.336385692615229e-10
# weighted outside (loss) fraction: 2.0193161996788323e-11
# weighted outside (loss) fraction: 1.6486900118619854e-10
# weighted outside (loss) fraction: 9.336409594954986e-10
# weighted outside (loss) fraction: 2.0412529674389157e-11
# weighted outside (loss) fraction: 1.6614973795304184e-10
# weighted outside (loss) fraction: 9.461486158316654e-10
# weighted outside (loss) fraction: 2.0422289918797537e-11
# weighted outside (loss) fraction: 1.6621160491376505e-10
# weighted outside (loss) fraction: 9.466705086029887e-10
# weighted outside (loss) fraction: 2.0643093335667658e-11
# weighted outside (loss) fraction: 1.6748847393092354e-10
# weighted outside (loss) fraction: 9.592709158172503e-10
# weighted outside (loss) fraction: 2.0643142130333305e-11
# weighted outside (loss) fraction: 1.6748883294880946e-10
# weighted outside (loss) fraction: 9.592732446033134e-10
# weighted outside (loss) fraction: 2.08657111018662e-11
# weighted outside (loss) fraction: 1.6878432015829466e-10
# weighted outside (loss) fraction: 9.720591579147081e-10
# weighted outside (loss) fraction: 2.0875458728566e-11
# weighted outside (loss) fraction: 1.68845883511334e-10
# weighted outside (loss) fraction: 9.725825359520574e-10
# weighted outside (loss) fraction: 2.1099878754891332e-11
# weighted outside (loss) fraction: 1.7013047676988083e-10
# weighted outside (loss) fraction: 9.85436050930951e-10
# weighted outside (loss) fraction: 2.1099926093521204e-11
# weighted outside (loss) fraction: 1.7013082380357363e-10
# weighted outside (loss) fraction: 9.854383171659475e-10
# weighted outside (loss) fraction: 2.1326041792717607e-11
# weighted outside (loss) fraction: 1.7145357377324125e-10
# weighted outside (loss) fraction: 9.98853211409674e-10
# weighted outside (loss) fraction: 2.1335780893142513e-11
# weighted outside (loss) fraction: 1.715148595223256e-10
# weighted outside (loss) fraction: 9.993784662325092e-10
# weighted outside (loss) fraction: 2.1563563855824365e-11
# weighted outside (loss) fraction: 1.727894077597788e-10
# weighted outside (loss) fraction: 1.012582642308834e-09
# weighted outside (loss) fraction: 2.1563609738961316e-11
# weighted outside (loss) fraction: 1.7278974311390656e-10
# weighted outside (loss) fraction: 1.01258484535541e-09
# weighted outside (loss) fraction: 2.1793102394531513e-11
# weighted outside (loss) fraction: 1.7408034566835888e-10
# weighted outside (loss) fraction: 1.0260639139240748e-09
# weighted outside (loss) fraction: 2.180283649993285e-11
# weighted outside (loss) fraction: 1.7414135044504064e-10
# weighted outside (loss) fraction: 1.0265911613854269e-09
# weighted outside (loss) fraction: 2.2034127501142875e-11
# weighted outside (loss) fraction: 1.7543707194497805e-10
# weighted outside (loss) fraction: 1.0400923362026797e-09
# weighted outside (loss) fraction: 2.2034171902744687e-11
# weighted outside (loss) fraction: 1.75437394943854e-10
# weighted outside (loss) fraction: 1.0400944751358525e-09
# weighted outside (loss) fraction: 2.2267420875404003e-11
# weighted outside (loss) fraction: 1.767506024882282e-10
# weighted outside (loss) fraction: 1.0538330559110916e-09
# weighted outside (loss) fraction: 2.2277154550815946e-11
# weighted outside (loss) fraction: 1.7681136884537664e-10
# weighted outside (loss) fraction: 1.0543625266390793e-09
# weighted outside (loss) fraction: 2.2511953930205914e-11
# weighted outside (loss) fraction: 1.7815501915238025e-10
# weighted outside (loss) fraction: 1.068082806366634e-09
# weighted outside (loss) fraction: 2.251199689992648e-11
# weighted outside (loss) fraction: 1.781553310083315e-10
# weighted outside (loss) fraction: 1.0680848805486014e-09
# weighted outside (loss) fraction: 2.2748667606973416e-11
# weighted outside (loss) fraction: 1.7950409162472399e-10
# weighted outside (loss) fraction: 1.0823308676361729e-09
# weighted outside (loss) fraction: 2.2758403836104427e-11
# weighted outside (loss) fraction: 1.7956465663573612e-10
# weighted outside (loss) fraction: 1.0828628121070675e-09
# weighted outside (loss) fraction: 2.299686820829622e-11
# weighted outside (loss) fraction: 1.809047231775934e-10
# weighted outside (loss) fraction: 1.0968827746787945e-09
# weighted outside (loss) fraction: 2.299690985964331e-11
# weighted outside (loss) fraction: 1.809050243883937e-10
# weighted outside (loss) fraction: 1.0968847904247397e-09
# weighted outside (loss) fraction: 2.3237424908117704e-11
# weighted outside (loss) fraction: 1.8226539589827063e-10
# weighted outside (loss) fraction: 1.1110167444314213e-09
# weighted outside (loss) fraction: 2.324716752404568e-11
# weighted outside (loss) fraction: 1.8232577336170474e-10
# weighted outside (loss) fraction: 1.1115511770071806e-09
# weighted outside (loss) fraction: 2.34894683898139e-11
# weighted outside (loss) fraction: 1.8366802528565363e-10
# weighted outside (loss) fraction: 1.1257698990790962e-09
# weighted outside (loss) fraction: 2.3489508917736392e-11
# weighted outside (loss) fraction: 1.8366831740245643e-10
# weighted outside (loss) fraction: 1.1257718648261583e-09
# weighted outside (loss) fraction: 2.373358903548923e-11
# weighted outside (loss) fraction: 1.8504856769325033e-10
# weighted outside (loss) fraction: 1.1402297277207044e-09
# weighted outside (loss) fraction: 2.374334118440026e-11
# weighted outside (loss) fraction: 1.8510877790258814e-10
# weighted outside (loss) fraction: 1.1407667892485008e-09
# weighted outside (loss) fraction: 2.3989328981238002e-11
# weighted outside (loss) fraction: 1.8648870090192141e-10
# weighted outside (loss) fraction: 1.1560225832523224e-09
# weighted outside (loss) fraction: 2.398936832659647e-11
# weighted outside (loss) fraction: 1.8648898364205264e-10
# weighted outside (loss) fraction: 1.1560244973833015e-09
# weighted outside (loss) fraction: 2.4237296940649434e-11
# weighted outside (loss) fraction: 1.878934211950462e-10
# weighted outside (loss) fraction: 1.170765074828441e-09
# weighted outside (loss) fraction: 2.4247062822305508e-11
# weighted outside (loss) fraction: 1.8795349179130236e-10
# weighted outside (loss) fraction: 1.17130532903289e-09
# weighted outside (loss) fraction: 2.4496915327418952e-11
# weighted outside (loss) fraction: 1.893654659814688e-10
# weighted outside (loss) fraction: 1.1862823099210817e-09
# weighted outside (loss) fraction: 2.4496953490774686e-11
# weighted outside (loss) fraction: 1.89365739136404e-10
# weighted outside (loss) fraction: 1.186284169603672e-09
# weighted outside (loss) fraction: 2.4748933914318975e-11
# weighted outside (loss) fraction: 1.9080706742798804e-10
# weighted outside (loss) fraction: 1.201261680688858e-09
# weighted outside (loss) fraction: 2.475871675484537e-11
# weighted outside (loss) fraction: 1.908670426139136e-10
# weighted outside (loss) fraction: 1.201804999807136e-09
# weighted outside (loss) fraction: 2.5012586686760276e-11
# weighted outside (loss) fraction: 1.9229695586212533e-10
# weighted outside (loss) fraction: 1.2170532582060027e-09
# weighted outside (loss) fraction: 2.5012623643846248e-11
# weighted outside (loss) fraction: 1.9229721962830176e-10
# weighted outside (loss) fraction: 1.217055063906784e-09
# weighted outside (loss) fraction: 2.5268600543572104e-11
# weighted outside (loss) fraction: 1.937071752153275e-10
# weighted outside (loss) fraction: 1.2323884962707297e-09
# weighted outside (loss) fraction: 2.5278403842201697e-11
# weighted outside (loss) fraction: 1.9376705970795194e-10
# weighted outside (loss) fraction: 1.232935085825265e-09
# weighted outside (loss) fraction: 2.553636764282895e-11
# weighted outside (loss) fraction: 1.9520974871565472e-10
# weighted outside (loss) fraction: 1.2483485879698753e-09
# weighted outside (loss) fraction: 2.553640358568435e-11
# weighted outside (loss) fraction: 1.952100049871982e-10
# weighted outside (loss) fraction: 1.2483503460709846e-09
# weighted outside (loss) fraction: 2.5796387706691723e-11
# weighted outside (loss) fraction: 1.967292040669673e-10
# weighted outside (loss) fraction: 1.263943041184024e-09
# weighted outside (loss) fraction: 2.580621501315661e-11
# weighted outside (loss) fraction: 1.9678903994483516e-10
# weighted outside (loss) fraction: 1.2644930068189777e-09
# weighted outside (loss) fraction: 2.606825226943516e-11
# weighted outside (loss) fraction: 1.9826760363295945e-10
# weighted outside (loss) fraction: 1.280242461188014e-09
# weighted outside (loss) fraction: 2.6068286998674343e-11
# weighted outside (loss) fraction: 1.9826785111654433e-10
# weighted outside (loss) fraction: 1.2802441596191878e-09
# weighted outside (loss) fraction: 2.6332330874797457e-11
# weighted outside (loss) fraction: 1.9972408661147065e-10
# weighted outside (loss) fraction: 1.296158651932059e-09
# weighted outside (loss) fraction: 2.6342185216379618e-11
# weighted outside (loss) fraction: 1.9978388690657146e-10
# weighted outside (loss) fraction: 1.2967121791512616e-09
# weighted outside (loss) fraction: 2.6608410743599222e-11
# weighted outside (loss) fraction: 2.0125791853192874e-10
# weighted outside (loss) fraction: 1.3127499662628726e-09
# weighted outside (loss) fraction: 2.6608444551390815e-11
# weighted outside (loss) fraction: 2.0125815855509583e-10
# weighted outside (loss) fraction: 1.3127516237229476e-09
# weighted outside (loss) fraction: 2.6876799517796205e-11
# weighted outside (loss) fraction: 2.0272978209076236e-10
# weighted outside (loss) fraction: 1.3290115588080012e-09
# weighted outside (loss) fraction: 2.6886684033644565e-11
# weighted outside (loss) fraction: 2.0278955435093036e-10
# weighted outside (loss) fraction: 1.3295688256320276e-09
# weighted outside (loss) fraction: 2.715733851918156e-11
# weighted outside (loss) fraction: 2.0428368917609917e-10
# weighted outside (loss) fraction: 1.3459381424328182e-09
# weighted outside (loss) fraction: 2.715737148210923e-11
# weighted outside (loss) fraction: 2.0428392314164694e-10
# weighted outside (loss) fraction: 1.3459397579220695e-09
# weighted outside (loss) fraction: 2.743017715864709e-11
# weighted outside (loss) fraction: 2.058033317515346e-10
# weighted outside (loss) fraction: 1.3628881109265725e-09
# weighted outside (loss) fraction: 2.7440095522234626e-11
# weighted outside (loss) fraction: 2.0586310613586682e-10
# weighted outside (loss) fraction: 1.363449468505513e-09
# weighted outside (loss) fraction: 2.7715020663461517e-11
# weighted outside (loss) fraction: 2.073617923676647e-10
# weighted outside (loss) fraction: 1.3802875963282177e-09
# weighted outside (loss) fraction: 2.7715052578719095e-11
# weighted outside (loss) fraction: 2.0736201880612306e-10
# weighted outside (loss) fraction: 1.3802891613515285e-09
# weighted outside (loss) fraction: 2.7992268292678527e-11
# weighted outside (loss) fraction: 2.0885212476992957e-10
# weighted outside (loss) fraction: 1.3971785596118665e-09
# weighted outside (loss) fraction: 2.8002224205134353e-11
# weighted outside (loss) fraction: 2.089119043556896e-10
# weighted outside (loss) fraction: 1.3977441051721948e-09
# weighted outside (loss) fraction: 2.8281648328910353e-11
# weighted outside (loss) fraction: 2.1043013453355417e-10
# weighted outside (loss) fraction: 1.4152646702873183e-09
# weighted outside (loss) fraction: 2.8281678865628362e-11
# weighted outside (loss) fraction: 2.104303502389627e-10
# weighted outside (loss) fraction: 1.41526616827444e-09
# weighted outside (loss) fraction: 2.856366822139812e-11
# weighted outside (loss) fraction: 2.1196253005239697e-10
# weighted outside (loss) fraction: 1.4331111022308906e-09
# weighted outside (loss) fraction: 2.857366521676583e-11
# weighted outside (loss) fraction: 2.120223462536825e-10
# weighted outside (loss) fraction: 1.4336813951877593e-09
# weighted outside (loss) fraction: 2.8857819583353193e-11
# weighted outside (loss) fraction: 2.1356001042132184e-10
# weighted outside (loss) fraction: 1.4511798792850831e-09
# weighted outside (loss) fraction: 2.8857849142442256e-11
# weighted outside (loss) fraction: 2.1356021871934094e-10
# weighted outside (loss) fraction: 1.4511813310046914e-09
# weighted outside (loss) fraction: 2.914425978806981e-11
# weighted outside (loss) fraction: 2.1512794265838813e-10
# weighted outside (loss) fraction: 1.4687916734201158e-09
# weighted outside (loss) fraction: 2.915430030277285e-11
# weighted outside (loss) fraction: 2.151878146908899e-10
# weighted outside (loss) fraction: 1.46936648058019e-09
# weighted outside (loss) fraction: 2.9443121524662706e-11
# weighted outside (loss) fraction: 2.1674802960242506e-10
# weighted outside (loss) fraction: 1.4875856962335637e-09
# weighted outside (loss) fraction: 2.9443150162552506e-11
# weighted outside (loss) fraction: 2.1674823076302955e-10
# weighted outside (loss) fraction: 1.4875871048218671e-09
# weighted outside (loss) fraction: 2.973444936044174e-11
# weighted outside (loss) fraction: 2.1830610109770152e-10
# weighted outside (loss) fraction: 1.5061797008878417e-09
# weighted outside (loss) fraction: 2.9744536719506564e-11
# weighted outside (loss) fraction: 2.1836604384766157e-10
# weighted outside (loss) fraction: 1.5067596013906432e-09
# weighted outside (loss) fraction: 3.0038294851127244e-11
# weighted outside (loss) fraction: 2.19958095962922e-10
# weighted outside (loss) fraction: 1.5255852882183181e-09
# weighted outside (loss) fraction: 3.0038322585050256e-11
# weighted outside (loss) fraction: 2.1995829100270665e-10
# weighted outside (loss) fraction: 1.5255866516166557e-09
# weighted outside (loss) fraction: 3.03346322166459e-11
# weighted outside (loss) fraction: 2.2157194241865029e-10
# weighted outside (loss) fraction: 1.5442687964666938e-09
# weighted outside (loss) fraction: 3.034476972380929e-11
# weighted outside (loss) fraction: 2.216319805071254e-10
# weighted outside (loss) fraction: 1.5448539568763006e-09
# weighted outside (loss) fraction: 3.064349010077227e-11
# weighted outside (loss) fraction: 2.2320584462591235e-10
# weighted outside (loss) fraction: 1.5637997246517448e-09
# weighted outside (loss) fraction: 3.06435170381891e-11
# weighted outside (loss) fraction: 2.232060347415296e-10
# weighted outside (loss) fraction: 1.5638010423910255e-09
# weighted outside (loss) fraction: 3.0944622306650236e-11
# weighted outside (loss) fraction: 2.248191971811906e-10
# weighted outside (loss) fraction: 1.5829765455293663e-09
# weighted outside (loss) fraction: 3.095481338186284e-11
# weighted outside (loss) fraction: 2.248793418821302e-10
# weighted outside (loss) fraction: 1.5835670886532668e-09
# weighted outside (loss) fraction: 3.125859180192455e-11
# weighted outside (loss) fraction: 2.2652911883737793e-10
# weighted outside (loss) fraction: 1.6029228187190008e-09
# weighted outside (loss) fraction: 3.125861774038021e-11
# weighted outside (loss) fraction: 2.265293016799363e-10
# weighted outside (loss) fraction: 1.6029240891017157e-09
# weighted outside (loss) fraction: 3.156498164607958e-11
# weighted outside (loss) fraction: 2.281866218278784e-10
# weighted outside (loss) fraction: 1.6221658007979583e-09
# weighted outside (loss) fraction: 3.157522922371752e-11
# weighted outside (loss) fraction: 2.2824690152624243e-10
# weighted outside (loss) fraction: 1.6227617915022307e-09
# weighted outside (loss) fraction: 3.1884231262343e-11
# weighted outside (loss) fraction: 2.2993057699831386e-10
# weighted outside (loss) fraction: 1.6423012084592167e-09
# weighted outside (loss) fraction: 3.188425628729099e-11
# weighted outside (loss) fraction: 2.2993075211928663e-10
# weighted outside (loss) fraction: 1.6423024334325157e-09
# weighted outside (loss) fraction: 3.2195908165318307e-11
# weighted outside (loss) fraction: 2.316137393283659e-10
# weighted outside (loss) fraction: 1.6619923703758144e-09
# weighted outside (loss) fraction: 3.2206216269868913e-11
# weighted outside (loss) fraction: 2.316741875385614e-10
# weighted outside (loss) fraction: 1.6625939751766345e-09
# weighted outside (loss) fraction: 3.2520612182080094e-11
# weighted outside (loss) fraction: 2.334053663423801e-10
# weighted outside (loss) fraction: 1.683418305459901e-09
# weighted outside (loss) fraction: 3.25206362359131e-11
# weighted outside (loss) fraction: 2.3340553532322014e-10
# weighted outside (loss) fraction: 1.6834194787718375e-09
# weighted outside (loss) fraction: 3.283785070430668e-11
# weighted outside (loss) fraction: 2.3507518595574525e-10
# weighted outside (loss) fraction: 1.7035664552049886e-09
# weighted outside (loss) fraction: 3.284822116392202e-11
# weighted outside (loss) fraction: 2.351358066711137e-10
# weighted outside (loss) fraction: 1.7041741314288525e-09
# weighted outside (loss) fraction: 3.316834055349507e-11
# weighted outside (loss) fraction: 2.368390721676716e-10
# weighted outside (loss) fraction: 1.7244667382460213e-09
# weighted outside (loss) fraction: 3.316836410622532e-11
# weighted outside (loss) fraction: 2.368392381486773e-10
# weighted outside (loss) fraction: 1.7244678840026432e-09
# weighted outside (loss) fraction: 3.3491074021520996e-11
# weighted outside (loss) fraction: 2.385533479311671e-10
# weighted outside (loss) fraction: 1.7448990619786348e-09
# weighted outside (loss) fraction: 3.3501510675119994e-11
# weighted outside (loss) fraction: 2.3861415586711727e-10
# weighted outside (loss) fraction: 1.745512641168227e-09
# weighted outside (loss) fraction: 3.38269938585808e-11
# weighted outside (loss) fraction: 2.4041365442942596e-10
# weighted outside (loss) fraction: 1.7661970085439157e-09
# weighted outside (loss) fraction: 3.382701668237547e-11
# weighted outside (loss) fraction: 2.404138154206863e-10
# weighted outside (loss) fraction: 1.7661981136345969e-09
# weighted outside (loss) fraction: 3.4155425396301505e-11
# weighted outside (loss) fraction: 2.4219538901102507e-10
# weighted outside (loss) fraction: 1.7870954377160087e-09
# weighted outside (loss) fraction: 3.416593174928447e-11
# weighted outside (loss) fraction: 2.4225642851425455e-10
# weighted outside (loss) fraction: 1.7877151208870436e-09
# weighted outside (loss) fraction: 3.4497258610369495e-11
# weighted outside (loss) fraction: 2.439933021852681e-10
# weighted outside (loss) fraction: 1.808843824969874e-09
# weighted outside (loss) fraction: 3.4497280623488896e-11
# weighted outside (loss) fraction: 2.4399345745573296e-10
# weighted outside (loss) fraction: 1.8088448869527285e-09
# weighted outside (loss) fraction: 3.483153905429166e-11
# weighted outside (loss) fraction: 2.457898318523892e-10
# weighted outside (loss) fraction: 1.8301783145202442e-09
# weighted outside (loss) fraction: 3.484211839934789e-11
# weighted outside (loss) fraction: 2.458511035092474e-10
# weighted outside (loss) fraction: 1.8308043115338856e-09
# weighted outside (loss) fraction: 3.517931397088105e-11
# weighted outside (loss) fraction: 2.4763871197290173e-10
# ...
# weighted outside (loss) fraction: 2.1112553218975795e-09
# weighted outside (loss) fraction: 3.916403199983056e-11
# weighted outside (loss) fraction: 2.684606476843283e-10
# weighted outside (loss) fraction: 2.1119240706129843e-09
# weighted outside (loss) fraction: 3.9540543724600604e-11
# weighted outside (loss) fraction: 2.7039203576595405e-10
# weighted outside (loss) fraction: 2.137343152949623e-09
# weighted outside (loss) fraction: 3.954055984920665e-11
# weighted outside (loss) fraction: 2.703921516314237e-10
# weighted outside (loss) fraction: 2.1373438932645904e-09
# weighted outside (loss) fraction: 3.992046421906188e-11
# weighted outside (loss) fraction: 2.7235565105208253e-10
# weighted outside (loss) fraction: 2.162337946471594e-09
# weighted outside (loss) fraction: 3.9931641859723205e-11
# weighted outside (loss) fraction: 2.7241897833603333e-10
# weighted outside (loss) fraction: 2.1630147019201234e-09
# weighted outside (loss) fraction: 4.0315377442113125e-11
# weighted outside (loss) fraction: 2.744156787797009e-10
# weighted outside (loss) fraction: 2.1891570808470252e-09
# weighted outside (loss) fraction: 4.031539279519535e-11
# weighted outside (loss) fraction: 2.744157899825059e-10
# weighted outside (loss) fraction: 2.1891577768143487e-09
# weighted outside (loss) fraction: 4.0702836320342696e-11
# weighted outside (loss) fraction: 2.763800583303072e-10
# weighted outside (loss) fraction: 2.2146618827932963e-09
# weighted outside (loss) fraction: 4.0714112140343324e-11
# weighted outside (loss) fraction: 2.764437413796721e-10
# weighted outside (loss) fraction: 2.215346887864093e-09
# weighted outside (loss) fraction: 4.110511227794798e-11
# weighted outside (loss) fraction: 2.7844076974867176e-10
# weighted outside (loss) fraction: 2.2415385637040274e-09
# weighted outside (loss) fraction: 4.110512728725605e-11
# weighted outside (loss) fraction: 2.7844088016394204e-10
# weighted outside (loss) fraction: 2.2415392254219827e-09
# weighted outside (loss) fraction: 4.149971156246551e-11
# weighted outside (loss) fraction: 2.804479728296148e-10
# weighted outside (loss) fraction: 2.2680318403459116e-09
# weighted outside (loss) fraction: 4.151108874546641e-11
# weighted outside (loss) fraction: 2.805120295307984e-10
# weighted outside (loss) fraction: 2.2687252709682543e-09
# weighted outside (loss) fraction: 4.190967328517622e-11
# weighted outside (loss) fraction: 2.825776437650056e-10
# weighted outside (loss) fraction: 2.2955204870307643e-09
# weighted outside (loss) fraction: 4.190968733507326e-11
# weighted outside (loss) fraction: 2.8257774811504804e-10
# weighted outside (loss) fraction: 2.295521093485691e-09
# weighted outside (loss) fraction: 4.2311973787436454e-11
# weighted outside (loss) fraction: 2.8466286785876915e-10
# weighted outside (loss) fraction: 2.3227603203593386e-09
# weighted outside (loss) fraction: 4.2323455371470095e-11
# weighted outside (loss) fraction: 2.847273256223892e-10
# weighted outside (loss) fraction: 2.3234624128403942e-09
# weighted outside (loss) fraction: 4.272968083926229e-11
# weighted outside (loss) fraction: 2.8681594152191007e-10
# weighted outside (loss) fraction: 2.350730339045943e-09
# weighted outside (loss) fraction: 4.2729694351086e-11
# weighted outside (loss) fraction: 2.868160420924548e-10
# weighted outside (loss) fraction: 2.3507309137654667e-09
# weighted outside (loss) fraction: 4.313991513452862e-11
# weighted outside (loss) fraction: 2.8891577394138575e-10
# weighted outside (loss) fraction: 2.3781643602018937e-09
# weighted outside (loss) fraction: 4.315150397042853e-11
# weighted outside (loss) fraction: 2.889806393984615e-10
# weighted outside (loss) fraction: 2.3788751441168525e-09
# weighted outside (loss) fraction: 4.356585383100547e-11
# weighted outside (loss) fraction: 2.9112549423984283e-10
# weighted outside (loss) fraction: 2.4075274486108683e-09
# weighted outside (loss) fraction: 4.356586688101444e-11
# weighted outside (loss) fraction: 2.911255940238039e-10
# weighted outside (loss) fraction: 2.407527984834467e-09
# weighted outside (loss) fraction: 4.398423483888863e-11
# weighted outside (loss) fraction: 2.9328947062393463e-10
# weighted outside (loss) fraction: 2.435807414914669e-09
# weighted outside (loss) fraction: 4.399593539882161e-11
# weighted outside (loss) fraction: 2.933547902526222e-10
# weighted outside (loss) fraction: 2.4365274137149615e-09
# weighted outside (loss) fraction: 4.44185225242942e-11
# weighted outside (loss) fraction: 2.9548218380204717e-10
# weighted outside (loss) fraction: 2.4651830442018975e-09
# weighted outside (loss) fraction: 4.4418534204182775e-11
# weighted outside (loss) fraction: 2.95482271453996e-10
# weighted outside (loss) fraction: 2.4651835250633383e-09
# weighted outside (loss) fraction: 4.484538733897373e-11
# weighted outside (loss) fraction: 2.976265357065601e-10
# weighted outside (loss) fraction: 2.493879330245493e-09
# weighted outside (loss) fraction: 4.485720173457177e-11
# weighted outside (loss) fraction: 2.976922872754295e-10
# weighted outside (loss) fraction: 2.494608488227583e-09
# weighted outside (loss) fraction: 4.528826161504768e-11
# weighted outside (loss) fraction: 2.998816559660321e-10
# weighted outside (loss) fraction: 2.5235811946942283e-09
# weighted outside (loss) fraction: 4.528827275685028e-11
# weighted outside (loss) fraction: 2.998817418587649e-10
# weighted outside (loss) fraction: 2.523581628989768e-09
# weighted outside (loss) fraction: 4.572337039599811e-11
# weighted outside (loss) fraction: 3.0210387201597506e-10
# weighted outside (loss) fraction: 2.5529007793849282e-09
# weighted outside (loss) fraction: 4.573530161839792e-11
# weighted outside (loss) fraction: 3.02170083905457e-10
# weighted outside (loss) fraction: 2.5536391748897724e-09
# weighted outside (loss) fraction: 4.6175018262196236e-11
# weighted outside (loss) fraction: 3.044585567306595e-10
# weighted outside (loss) fraction: 2.5833702758548e-09
# weighted outside (loss) fraction: 4.617502904205292e-11
# weighted outside (loss) fraction: 3.0445864191563087e-10
# weighted outside (loss) fraction: 2.583370674968478e-09
# weighted outside (loss) fraction: 4.661904167930745e-11
# weighted outside (loss) fraction: 3.067170997177891e-10
# weighted outside (loss) fraction: 2.613724457471727e-09
# weighted outside (loss) fraction: 4.663109333943023e-11
# weighted outside (loss) fraction: 3.067838066022051e-10
# weighted outside (loss) fraction: 2.614472409313554e-09
# weighted outside (loss) fraction: 4.707957711102235e-11
# weighted outside (loss) fraction: 3.0900595935249366e-10
# weighted outside (loss) fraction: 2.6448753795307224e-09
# weighted outside (loss) fraction: 4.707958717468685e-11
# weighted outside (loss) fraction: 3.090060391433303e-10
# weighted outside (loss) fraction: 2.644875742976529e-09
# weighted outside (loss) fraction: 4.753249436379748e-11
# weighted outside (loss) fraction: 3.1132797273802863e-10
# weighted outside (loss) fraction: 2.675967020875067e-09
# weighted outside (loss) fraction: 4.7544669492127395e-11
# weighted outside (loss) fraction: 3.113951744106031e-10
# weighted outside (loss) fraction: 2.6767247803280007e-09
# weighted outside (loss) fraction: 4.800217730172761e-11
# weighted outside (loss) fraction: 3.137280709846182e-10
# weighted outside (loss) fraction: 2.707837110308758e-09
# weighted outside (loss) fraction: 4.800218645949993e-11
# weighted outside (loss) fraction: 3.137281468561145e-10
# weighted outside (loss) fraction: 2.707837403065548e-09
# weighted outside (loss) fraction: 4.8464575707328654e-11
# weighted outside (loss) fraction: 3.160335255775919e-10
# weighted outside (loss) fraction: 2.739373141613213e-09
# weighted outside (loss) fraction: 4.847687711084817e-11
# weighted outside (loss) fraction: 3.161012357895404e-10
# weighted outside (loss) fraction: 2.7401408134087014e-09
# weighted outside (loss) fraction: 4.894395651775839e-11
# weighted outside (loss) fraction: 3.1842862085421263e-10
# weighted outside (loss) fraction: 2.7734273719747557e-09
# weighted outside (loss) fraction: 4.894396511906698e-11
# weighted outside (loss) fraction: 3.184286931597543e-10
# weighted outside (loss) fraction: 2.7734276275895916e-09
# weighted outside (loss) fraction: 4.941597424528868e-11
# weighted outside (loss) fraction: 3.207810639411939e-10
# weighted outside (loss) fraction: 2.806111789982339e-09
# weighted outside (loss) fraction: 4.9428405044612346e-11
# weighted outside (loss) fraction: 3.2084929358030086e-10
# weighted outside (loss) fraction: 2.806890045434252e-09
# weighted outside (loss) fraction: 4.9905140643158386e-11
# weighted outside (loss) fraction: 3.232766014399255e-10
# weighted outside (loss) fraction: 2.8404255529468373e-09
# weighted outside (loss) fraction: 4.990514846702528e-11
# weighted outside (loss) fraction: 3.2327666825876723e-10
# weighted outside (loss) fraction: 2.840425755260668e-09
# weighted outside (loss) fraction: 5.038689011911175e-11
# weighted outside (loss) fraction: 3.256454675511206e-10
# weighted outside (loss) fraction: 2.8737935061597503e-09
# weighted outside (loss) fraction: 5.039945299107525e-11
# weighted outside (loss) fraction: 3.2571422731808827e-10
# weighted outside (loss) fraction: 2.874582380952684e-09
# weighted outside (loss) fraction: 5.088614913247353e-11
# weighted outside (loss) fraction: 3.281251382815449e-10
# weighted outside (loss) fraction: 2.9080516863690865e-09
# weighted outside (loss) fraction: 5.0886156427234304e-11
# weighted outside (loss) fraction: 3.2812520236032364e-10
# weighted outside (loss) fraction: 2.9080518591424674e-09
# weighted outside (loss) fraction: 5.13777921516732e-11
# weighted outside (loss) fraction: 3.305717892689316e-10
# weighted outside (loss) fraction: 2.9422960581259473e-09
# weighted outside (loss) fraction: 5.139049181613931e-11
# weighted outside (loss) fraction: 3.306411040917689e-10
# weighted outside (loss) fraction: 2.943095588777838e-09
# weighted outside (loss) fraction: 5.188752725831363e-11
# weighted outside (loss) fraction: 3.3305434364377997e-10
# weighted outside (loss) fraction: 2.977555877692877e-09
# weighted outside (loss) fraction: 5.1887533451065135e-11
# weighted outside (loss) fraction: 3.330544005836522e-10
# weighted outside (loss) fraction: 2.977555985932349e-09
# weighted outside (loss) fraction: 5.238973560617837e-11
# weighted outside (loss) fraction: 3.3554119283234525e-10
# weighted outside (loss) fraction: 3.0127737783160944e-09
# weighted outside (loss) fraction: 5.240257373030492e-11
# weighted outside (loss) fraction: 3.3561105853416943e-10
# weighted outside (loss) fraction: 3.0135842239623097e-09
# weighted outside (loss) fraction: 5.291012374523781e-11
# weighted outside (loss) fraction: 3.3811939947456493e-10
# weighted outside (loss) fraction: 3.0487906112598757e-09
# weighted outside (loss) fraction: 5.2910129663149455e-11
# weighted outside (loss) fraction: 3.3811945762373627e-10
# weighted outside (loss) fraction: 3.048790671186057e-09
# weighted outside (loss) fraction: 5.342293457977659e-11
# weighted outside (loss) fraction: 3.4065385544175577e-10
# weighted outside (loss) fraction: 3.0844426951347252e-09
# weighted outside (loss) fraction: 5.3435913789274174e-11
# weighted outside (loss) fraction: 3.407242930404873e-10
# weighted outside (loss) fraction: 3.0852641136886854e-09
# weighted outside (loss) fraction: 5.395414700748882e-11
# weighted outside (loss) fraction: 3.4330501881852617e-10
# weighted outside (loss) fraction: 3.1212817892879895e-09
# weighted outside (loss) fraction: 5.395415255508162e-11
# weighted outside (loss) fraction: 3.4330507623073624e-10
# weighted outside (loss) fraction: 3.1212818040117478e-09
# weighted outside (loss) fraction: 5.4477882726979534e-11
# weighted outside (loss) fraction: 3.4586066490568786e-10
# weighted outside (loss) fraction: 3.1578760755617907e-09
# weighted outside (loss) fraction: 5.4491007406766845e-11
# weighted outside (loss) fraction: 3.459317045686055e-10
# weighted outside (loss) fraction: 3.158708662136143e-09
# weighted outside (loss) fraction: 5.5020495847825033e-11
# weighted outside (loss) fraction: 3.4852706406637493e-10
# weighted outside (loss) fraction: 3.1969777501057844e-09
# weighted outside (loss) fraction: 5.502050022460467e-11
# weighted outside (loss) fraction: 3.485271126528137e-10
# weighted outside (loss) fraction: 3.1969777131982055e-09
# weighted outside (loss) fraction: 5.555556951760886e-11
# weighted outside (loss) fraction: 3.5113288766025693e-10
# weighted outside (loss) fraction: 3.2344203654103845e-09
# weighted outside (loss) fraction: 5.5568841140838865e-11
# weighted outside (loss) fraction: 3.5120452152562495e-10
# weighted outside (loss) fraction: 3.2352646596661407e-09
# weighted outside (loss) fraction: 5.610976657101517e-11
# weighted outside (loss) fraction: 3.5384139993020087e-10
# weighted outside (loss) fraction: 3.2737922478924075e-09
# weighted outside (loss) fraction: 5.610977040394526e-11
# weighted outside (loss) fraction: 3.538414463603496e-10
# weighted outside (loss) fraction: 3.273792158841812e-09
# weighted outside (loss) fraction: 5.6656514390716105e-11
# weighted outside (loss) fraction: 3.565292901226793e-10
# weighted outside (loss) fraction: 3.3126429880315435e-09
# weighted outside (loss) fraction: 5.666993682500674e-11
# weighted outside (loss) fraction: 3.566015414224104e-10
# weighted outside (loss) fraction: 3.313499159922873e-09
# weighted outside (loss) fraction: 5.722266250374419e-11
# weighted outside (loss) fraction: 3.592733717269892e-10
# weighted outside (loss) fraction: 3.352379691594626e-09
# weighted outside (loss) fraction: 5.722266565309999e-11
# weighted outside (loss) fraction: 3.592734143496748e-10
# weighted outside (loss) fraction: 3.352379541810909e-09
# weighted outside (loss) fraction: 5.778115597217069e-11
# weighted outside (loss) fraction: 3.6197344663374456e-10
# weighted outside (loss) fraction: 3.3942955249459706e-09
# weighted outside (loss) fraction: 5.7794732528565516e-11
# weighted outside (loss) fraction: 3.6204633031466043e-10
# weighted outside (loss) fraction: 3.395164120603291e-09
# weighted outside (loss) fraction: 5.835929154175815e-11
# weighted outside (loss) fraction: 3.647757856896657e-10
# weighted outside (loss) fraction: 3.4328169330243617e-09
# weighted outside (loss) fraction: 5.835929366411399e-11
# weighted outside (loss) fraction: 3.647758219184259e-10
# weighted outside (loss) fraction: 3.432816722501303e-09
# weighted outside (loss) fraction: 5.89300448550589e-11
# weighted outside (loss) fraction: 3.6755631335355287e-10
# weighted outside (loss) fraction: 3.473933216721105e-09
# weighted outside (loss) fraction: 5.894377692927404e-11
# weighted outside (loss) fraction: 3.6762983535513117e-10
# weighted outside (loss) fraction: 3.4748133875160936e-09
# weighted outside (loss) fraction: 5.95206930111785e-11
# weighted outside (loss) fraction: 3.7043176079032286e-10
# weighted outside (loss) fraction: 3.516129358977458e-09
# weighted outside (loss) fraction: 5.95206948553179e-11
# weighted outside (loss) fraction: 3.7043179672119237e-10
# weighted outside (loss) fraction: 3.516129112967735e-09
# weighted outside (loss) fraction: 6.010396315097797e-11
# weighted outside (loss) fraction: 3.732741186558495e-10
# weighted outside (loss) fraction: 3.558157374311644e-09
# weighted outside (loss) fraction: 6.011785483514428e-11
# weighted outside (loss) fraction: 3.733483044371274e-10
# weighted outside (loss) fraction: 3.5590499867184763e-09
# weighted outside (loss) fraction: 6.070749524716221e-11
# weighted outside (loss) fraction: 3.7623336550320054e-10
# weighted outside (loss) fraction: 3.601229609967759e-09
# weighted outside (loss) fraction: 6.070749593357741e-11
# weighted outside (loss) fraction: 3.7623339400665956e-10
# weighted outside (loss) fraction: 3.601229280151771e-09
# weighted outside (loss) fraction: 6.130372552649032e-11
# weighted outside (loss) fraction: 3.7910159350248017e-10
# weighted outside (loss) fraction: 3.643993860881901e-09
# weighted outside (loss) fraction: 6.131777911048419e-11
# weighted outside (loss) fraction: 3.7917644646660096e-10
# weighted outside (loss) fraction: 3.644898971566188e-09
# weighted outside (loss) fraction: 6.192078822199774e-11
# weighted outside (loss) fraction: 3.821250330996807e-10
# weighted outside (loss) fraction: 3.6887211726906685e-09

# %%
q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)

a_1 = torch.tensor(a1, device=device, dtype=dtype)



# Physical p, E
p = q/a1

p_cpu  = p.detach().cpu().numpy()
fall_cpu = fall.detach().cpu().numpy()

plt.figure()
plt.plot(p_cpu, fall_cpu)
plt.xlabel("p")
#plt.xscale("log")
plt.ylabel("f_all(p)")
plt.yscale("log")
plt.title("f(p) at final a")
plt.grid(True)
plt.show()

plt.figure()
plt.semilogy(p_cpu, np.maximum(fall_cpu, 1e-300))
plt.xlabel("p")
plt.xscale("log")

plt.ylabel("f_all(p)")
plt.title("f(p) at final a (log scale)")
plt.grid(True, which="both")
plt.show()

# %%
plt.figure()
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(f1_cpu, 1e-300))
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fall_cpu, 1e-300))
#plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fan, 1e-300))

#plt.ylim(10**(-9),1.5*10**(-6))   # set y-axis range
#plt.xlim(10**(-3),10**(1))   # set y-axis range

plt.xlabel("p")
plt.xscale("log")


plt.ylabel(r"$p^2 f(p)$")
plt.yscale("linear")


plt.title(r"$p^2 f(p)$ at final a")
plt.grid(True, which="both")
#plt.show()

# %%
fall
# Out:
# tensor([3.5870e-09, 3.5870e-09, 3.5870e-09, 3.5870e-09, 3.5870e-09, 3.5869e-09,
#         3.5869e-09, 3.5869e-09, 3.5868e-09, 3.5867e-09, 3.5866e-09, 3.5864e-09,
#         3.5862e-09, 3.5859e-09, 3.5854e-09, 3.5849e-09, 3.5841e-09, 3.5830e-09,
#         3.5815e-09, 3.5795e-09, 3.5768e-09, 3.5731e-09, 3.5680e-09, 3.5612e-09,
#         3.5520e-09, 3.5395e-09, 3.5229e-09, 3.5007e-09, 3.4713e-09, 3.4328e-09,
#         3.3830e-09, 3.3192e-09, 3.2388e-09, 3.1390e-09, 3.0172e-09, 2.8713e-09,
#         2.7002e-09, 2.5042e-09, 2.2855e-09, 2.0487e-09, 1.8005e-09, 1.5497e-09,
#         1.3057e-09, 1.0772e-09, 8.7117e-10, 6.9187e-10, 5.4074e-10, 4.1686e-10,
#         3.1769e-10, 2.3984e-10, 1.7969e-10, 1.3380e-10, 9.9145e-11, 7.3174e-11,
#         5.3830e-11, 3.9490e-11, 2.8902e-11, 2.1108e-11, 1.5386e-11, 1.1192e-11,
#         8.1254e-12, 5.8862e-12, 4.2542e-12, 3.0667e-12, 2.2040e-12, 1.5787e-12,
#         1.1263e-12, 7.9992e-13, 5.6511e-13, 3.9676e-13, 2.7657e-13, 1.9117e-13,
#         1.3085e-13, 8.8538e-14, 5.9111e-14, 3.8851e-14, 2.5072e-14, 1.5838e-14,
#         9.7577e-15, 5.8390e-15, 3.3769e-15, 1.8768e-15, 9.9573e-16, 5.0035e-16,
#         2.3598e-16, 1.0335e-16, 4.1510e-17, 1.5070e-17, 4.8624e-18, 1.3669e-18],
#        dtype=torch.float64)

# %%
import collision_log
from collision_log import C_self_with_F_torch_batched_logq #, enforce_number_energy

Ng = 128          # angular quadrature order
batch_size = 32

#q, dq = make_uniform_q_grid(qmin, qmax, N, device=device, dtype=dtype)

#a_t = torch.tensor(a, device=device, dtype=dtype)
#m_t = torch.tensor(m, device=device, dtype=dtype)



#Tt = torch.tensor(Tchi, device=device, dtype=dtype)
#f = f_MB_torch(E, Tt, A=1.0)
#f = torch.ones_like(p)      # safest: matches shape, dtype, device


#C , E_out, p_out, dp = C_self_with_F_torch_batched_snapped(
#    f, a_t, q, dq, m_t,
#    lam=lam, gchi=1.0,
#    Ng=Ng, batch_size=batch_size,
#    snap_mode="nearest",          # "nearest" or "floor"
#    return_debug=False
#)

C, E_out, p_out, dp = C_self_with_F_torch_batched_logq(
    fall, a1,
    q, logq0, dlogq, log_space,
    m_med, lam=lam, gchi=1.0,
    Ng=32, batch_size=16
)

#C, E_out, p_out, dp = C_self_plumbing_torch_batched(f, a_t, q, dq, m_t, gchi=1.0, batch_size=16)
# Out:
# weighted outside (loss) fraction: 4.781191519240451e-11
# weighted outside (loss) fraction: 9.812043400540505e-11
# weighted outside (loss) fraction: 3.5989217128364714e-10
# weighted outside (loss) fraction: 2.3859028252647245e-09
# weighted outside (loss) fraction: 3.636014625115199e-09
# weighted outside (loss) fraction: 1.469778182967161e-09

# %%
#C2 = enforce_number_energy(C, p, E, dp, eps=0.0)

# Plot
p_cpu = p_out.detach().cpu().numpy()
C_cpu = C.detach().cpu().numpy()

# Plot
#C_cpu2 = C2.detach().cpu().numpy()

plt.figure()

plt.plot(p_cpu, C_cpu, label="C_cpu")
#plt.plot(p_cpu, C_cpu2, label="C_cpu2")

plt.yscale("symlog")
plt.xlabel("p")
plt.xscale("log")


plt.ylabel("C_self(p)")
#plt.title("Collision term for MB input (should be ~0)")
plt.grid(True)
plt.legend()

plt.show()


print("max|C| =", float(torch.max(torch.abs(C))))
# Out:
# max|C| = 1.135196490534891e-24

# %% [markdown]
# # Now with the collision operator having elastic scattering $AA\to AA$

# %%
alpha = 1/137


# Rough width: Gamma ~ alpha * eps^2 * m
lam = 0.001
g = 0.08
v = 1
mA = g*v
mh = np.sqrt(lam/3)*v

eps = 6e-10
Gamma = alpha * eps**2 * mA

Gamma = gamma_ap_total_to_sm_fermions(
    mA, eps,
    alpha_em=1/137.035999084,
    include=("e","mu","tau","u","d","s","c","b","t"),
)

gchi = 1.
lam = 1e-3

#m_med = 0.018
#m_med = mA

# %%
# Choose grid and params (keep modest while testing)
from collision_log import rhs_df_da_torch_logq_t,rhs_dfFI_da_torch
from functools import partial

N = 50
qmin = 10**(-3)
qmax = 10**2
a0 = 1
a1 = 4.

batch_size = 32

n_steps = 40
Ng=32

q, logq0, dlogq, log_space = mygrid(qmin, qmax, N)

f0 = torch.zeros_like(q)   # (N,)

rhsFI = partial(
    rhs_dfFI_da_torch,
    q=q, dq=dlogq, m=mA, lam=lam,
    H_of_a=H_of_a, T_of_a=T_of_a,
    m_med=mA, Gamma=Gamma, pref_FI=1.0,
    gchi=gchi, batch_size=batch_size
)

f1 = integrate_rk4_a(f0, a0, a1, n_steps, rhsFI)

rhs_t = partial(
    rhs_df_da_torch_logq_t,
    q=q,
    logq0=logq0,
    dlogq=dlogq,
    log_space=log_space,
    mA=mA,
    mh=mh,
    g=g,
    H_of_a=H_of_a,
    T_of_a=T_of_a,
    m_med=mA,
    Gamma=Gamma,
    pref_FI=1.0,
    gchi=gchi,
    batch_size=batch_size,
)

a_hist, f_hist = integrate_rk4_a_trajectory(
    f0=f0, a0=a0, a1=a1, n_steps=n_steps, rhs=rhs_t,
    store_every=1,
    print_every_pct=10,
    out_path_pt="traj.pt",
    out_path_dat="traj.dat",   # readable in TextEdit/Mathematica
    atomic=True,
)
# Out:
# 10% done!
# 20% done!
# 30% done!
# 40% done!
# 50% done!
# 60% done!
# 70% done!
# 80% done!
# 90% done!
# 100% done!

# %%
# Physical p, E
p = q/a1

p_cpu  = p.detach().cpu().numpy()
fall_cpu = f_hist[-1].detach().cpu().numpy()
f1_cpu = f1.detach().cpu().numpy()

plt.figure()
plt.plot(p_cpu, fall_cpu)
plt.plot(p_cpu, f1_cpu)

plt.xlabel("p")
#plt.xscale("log")
plt.ylabel("f_all(p)")
plt.yscale("log")
plt.title("f(p) at final a")
plt.grid(True)
plt.show()

plt.figure()
plt.semilogy(p_cpu, np.maximum(fall_cpu, 1e-300))
plt.xlabel("p")
plt.xscale("log")

plt.ylabel("f_all(p)")
plt.title("f(p) at final a (log scale)")
plt.grid(True, which="both")
plt.show()

# %%
plt.figure()
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(f1_cpu, 1e-300))
plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fall_cpu, 1e-300))
#plt.semilogy(p_cpu, p_cpu**2 * np.maximum(fan, 1e-300))

#plt.ylim(10**(-9),1.5*10**(-6))   # set y-axis range
#plt.xlim(10**(-3),10**(1))   # set y-axis range

plt.xlabel("p")
plt.xscale("log")


plt.ylabel(r"$p^2 f(p)$")
plt.yscale("linear")


plt.title(r"$p^2 f(p)$ at final a")
plt.grid(True, which="both")
#plt.show()
