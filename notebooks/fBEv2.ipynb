# %%
# --- System / path ---
import sys
from pathlib import Path

ROOT = Path.cwd()
SRC = ROOT / "src"
FILES = ROOT / "files"

if str(SRC) not in sys.path:
    sys.path.append(str(SRC))

print("Root:", ROOT)
print("Src:", SRC)
print("Files:", FILES)
# Out:
# Root: /Users/esau/Dropbox/fBE_ML
# Src: /Users/esau/Dropbox/fBE_ML/src
# Files: /Users/esau/Dropbox/fBE_ML/files

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

import torch

# Choose device
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float64

print("Using device:", device)
# Out:
# Using device: cpu

# %%
from grid_np import (
    make_uniform_q_grid,
    make_log_q_grid,
)

from collision_np import (
    C_self_plumbing_numpy,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from grid_np import (
#       2     make_uniform_q_grid,
#       3     make_log_q_grid,
#       4 )
#       6 from collision_np import (
#       7     C_self_plumbing_numpy,
#       8 )
#
# ImportError: cannot import name 'make_uniform_q_grid' from 'grid_np' (/Users/esau/Dropbox/fBE_ML/src/grid_np.py)
